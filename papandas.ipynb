# %%
import pandas as pd

df = pd.read_csv('IRIS_dataset.csv')

print(df.to_string())
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      flower
# 0            5.1          3.5           1.4          0.2      setosa
# 1            4.9          3.0           1.4          0.2      setosa
# 2            4.7          3.2           1.3          0.2      setosa
# 3            4.6          3.1           1.5          0.2      setosa
# 4            5.0          3.6           1.4          0.2      setosa
# 5            5.4          3.9           1.7          0.4      setosa
# 6            4.6          3.4           1.4          0.3      setosa
# 7            5.0          3.4           1.5          0.2      setosa
# 8            4.4          2.9           1.4          0.2      setosa
# 9            4.9          3.1           1.5          0.1      setosa
# 10           5.4          3.7           1.5          0.2      setosa
# 11           4.8          3.4           1.6          0.2      setosa
# 12           4.8          3.0           1.4          0.1      setosa
# 13           4.3          3.0           1.1          0.1      setosa
# 14           5.8          4.0           1.2          0.2      setosa
# 15           5.7          4.4           1.5          0.4      setosa
# 16           5.4          3.9           1.3          0.4      setosa
# 17           5.1          3.5           1.4          0.3      setosa
# 18           5.7          3.8           1.7          0.3      setosa
# 19           5.1          3.8           1.5          0.3      setosa
# 20           5.4          3.4           1.7          0.2      setosa
# 21           5.1          3.7           1.5          0.4      setosa
# 22           4.6          3.6           1.0          0.2      setosa
# 23           5.1          3.3           1.7          0.5      setosa
# 24           4.8          3.4           1.9          0.2      setosa
# 25           5.0          3.0           1.6          0.2      setosa
# 26           5.0          3.4           1.6          0.4      setosa
# 27           5.2          3.5           1.5          0.2      setosa
# 28           5.2          3.4           1.4          0.2      setosa
# 29           4.7          3.2           1.6          0.2      setosa
# 30           4.8          3.1           1.6          0.2      setosa
# 31           5.4          3.4           1.5          0.4      setosa
# 32           7.0          3.2           4.7          1.4  versicolor
# 33           6.4          3.2           4.5          1.5  versicolor
# 34           6.9          3.1           4.9          1.5  versicolor
# 35           5.5          2.3           4.0          1.3  versicolor
# 36           6.5          2.8           4.6          1.5  versicolor
# 37           5.7          2.8           4.5          1.3  versicolor
# 38           6.3          3.3           4.7          1.6  versicolor
# 39           4.9          2.4           3.3          1.0  versicolor
# 40           6.6          2.9           4.6          1.3  versicolor
# 41           5.2          2.7           3.9          1.4  versicolor
# 42           5.0          2.0           3.5          1.0  versicolor
# 43           5.9          3.0           4.2          1.5  versicolor
# 44           6.0          2.2           4.0          1.0  versicolor
# 45           6.1          2.9           4.7          1.4  versicolor
# 46           5.6          2.9           3.6          1.3  versicolor
# 47           6.7          3.1           4.4          1.4  versicolor
# 48           5.6          3.0           4.5          1.5  versicolor
# 49           5.8          2.7           4.1          1.0  versicolor
# 50           6.2          2.2           4.5          1.5  versicolor
# 51           5.6          2.5           3.9          1.1  versicolor
# 52           5.9          3.2           4.8          1.8  versicolor
# 53           6.1          2.8           4.0          1.3  versicolor
# 54           6.3          2.5           4.9          1.5  versicolor
# 55           6.1          2.8           4.7          1.2  versicolor
# 56           6.4          2.9           4.3          1.3  versicolor
# 57           6.6          3.0           4.4          1.4  versicolor
# 58           6.8          2.8           4.8          1.4  versicolor
# 59           6.7          3.0           5.0          1.7  versicolor
# 60           6.0          2.9           4.5          1.5  versicolor
# 61           5.7          2.6           3.5          1.0  versicolor
# 62           5.5          2.4           3.8          1.1  versicolor
# 63           5.5          2.4           3.7          1.0  versicolor
# 64           5.8          2.7           3.9          1.2  versicolor
# 65           6.0          2.7           5.1          1.6  versicolor
# 66           6.3          3.3           6.0          2.5   virginica
# 67           5.8          2.7           5.1          1.9   virginica
# 68           7.1          3.0           5.9          2.1   virginica
# 69           6.3          2.9           5.6          1.8   virginica
# 70           6.5          3.0           5.8          2.2   virginica
# 71           7.6          3.0           6.6          2.1   virginica
# 72           4.9          2.5           4.5          1.7   virginica
# 73           7.3          2.9           6.3          1.8   virginica
# 74           6.7          2.5           5.8          1.8   virginica
# 75           7.2          3.6           6.1          2.5   virginica
# 76           6.5          3.2           5.1          2.0   virginica
# 77           6.4          2.7           5.3          1.9   virginica
# 78           6.8          3.0           5.5          2.1   virginica
# 79           5.7          2.5           5.0          2.0   virginica
# 80           5.8          2.8           5.1          2.4   virginica
# 81           6.4          3.2           5.3          2.3   virginica
# 82           6.5          3.0           5.5          1.8   virginica
# 83           7.7          3.8           6.7          2.2   virginica
# 84           7.7          2.6           6.9          2.3   virginica
# 85           6.0          2.2           5.0          1.5   virginica
# 86           6.9          3.2           5.7          2.3   virginica
# 87           5.6          2.8           4.9          2.0   virginica
# 88           7.7          2.8           6.7          2.0   virginica
# 89           6.3          2.7           4.9          1.8   virginica
# 90           6.7          3.3           5.7          2.1   virginica
# 91           7.2          3.2           6.0          1.8   virginica
# 92           6.2          2.8           4.8          1.8   virginica
# 93           6.1          3.0           4.9          1.8   virginica
# 94           6.4          2.8           5.6          2.1   virginica
# 95           7.2          3.0           5.8          1.6   virginica
# 96           7.4          2.8           6.1          1.9   virginica
# 97           7.9          3.8           6.4          2.0   virginica
# 98           6.4          2.8           5.6          2.2   virginica
# 99           6.3          2.8           5.1          1.5   virginica

# %%
import pandas as pd

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pd.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd

df = pd.read_csv("IRIS_dataset.csv")

# Print full DataFrame
print(df)

# Print current max rows setting
print(pd.options.display.max_rows)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     flower
# 0            5.1          3.5           1.4          0.2     setosa
# 1            4.9          3.0           1.4          0.2     setosa
# 2            4.7          3.2           1.3          0.2     setosa
# 3            4.6          3.1           1.5          0.2     setosa
# 4            5.0          3.6           1.4          0.2     setosa
# ..           ...          ...           ...          ...        ...
# 95           7.2          3.0           5.8          1.6  virginica
# 96           7.4          2.8           6.1          1.9  virginica
# 97           7.9          3.8           6.4          2.0  virginica
# 98           6.4          2.8           5.6          2.2  virginica
# 99           6.3          2.8           5.1          1.5  virginica
#
# [100 rows x 5 columns]
# 60

# %%
import pandas as pd

data = {
  "Duration": {
    "0": 60,
    "1": 60,
    "2": 60,
    "3": 45,
    "4": 45,
    "5": 60
  },
  "Pulse": {
    "0": 110,
    "1": 117,
    "2": 103,
    "3": 109,
    "4": 117,
    "5": 102
  },
  "Maxpulse": {
    "0": 130,
    "1": 145,
    "2": 135,
    "3": 175,
    "4": 148,
    "5": 127
  },
  "Calories": {
    "0": 409,
    "1": 479,
    "2": 340,
    "3": 282,
    "4": 406,
    "5": 300
  }
}

df = pd.DataFrame(data)

# Convert DataFrame to JSON
json_data = df.to_json()

print(json_data)
# Out:
# {"Duration":{"0":60,"1":60,"2":60,"3":45,"4":45,"5":60},"Pulse":{"0":110,"1":117,"2":103,"3":109,"4":117,"5":102},"Maxpulse":{"0":130,"1":145,"2":135,"3":175,"4":148,"5":127},"Calories":{"0":409,"1":479,"2":340,"3":282,"4":406,"5":300}}

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([
    [2.5,2.4],[0.5,0.7],[2.2,2.9],[1.9,2.2],[3.1,3.0],
    [2.3,2.7],[2.0,1.6],[1.0,1.1],[1.5,1.6],[1.1,0.9]
])

mean = X.mean(axis=0)
Xc = X - mean

C = np.cov(Xc.T)
eigval,eigvec = np.linalg.eig(C)

idx = eigval.argsort()[::-1]
eigvec = eigvec[:,idx]

v1,v2 = eigvec[:,0], eigvec[:,1]

plt.scatter(X[:,0],X[:,1])
plt.scatter(mean[0],mean[1])

s=2
plt.quiver(mean[0],mean[1],v1[0]*s,v1[1]*s,
           angles='xy',scale_units='xy',scale=1)
plt.quiver(mean[0],mean[1],v2[0]*s,v2[1]*s,
           angles='xy',scale_units='xy',scale=1)

plt.grid()
plt.show()
