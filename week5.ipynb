# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Load data
X, y = load_iris(return_X_y=True)

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = KNeighborsClassifier(n_neighbors=3)
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9666666666666667

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# Load MNIST
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)

# Reduce size (important for speed)
X, y = X[:10000], y[:10000]

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = SVC(kernel='linear')
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 from sklearn.metrics import accuracy_score
#       6 # Load MNIST
# ----> 7 X, y = fetch_openml('mnist_784', version=1, return_X_y=True)
#       9 # Reduce size (important for speed)
#      10 X, y = X[:10000], y[:10000]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\datasets\_openml.py:1131, in fetch_openml(name, version, data_id, data_home, target_column, cache, return_X_y, as_frame, n_retries, delay, parser, read_csv_kwargs)
#    1129 # obtain the data
#    1130 url = data_description["url"]
# -> 1131 bunch = _download_data_to_bunch(
#    1132     url,
#    1133     return_sparse,
#    1134     data_home,
#    1135     as_frame=bool(as_frame),
#    1136     openml_columns_info=features_list,
#    1137     shape=shape,
#    1138     target_columns=target_columns,
#    1139     data_columns=data_columns,
#    1140     md5_checksum=data_description["md5_checksum"],
#    1141     n_retries=n_retries,
#    1142     delay=delay,
#    1143     parser=parser_,
#    1144     read_csv_kwargs=read_csv_kwargs,
#    1145 )
#    1147 if return_X_y:
#    1148     return bunch.data, bunch.target
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\datasets\_openml.py:685, in _download_data_to_bunch(url, sparse, data_home, as_frame, openml_columns_info, data_columns, target_columns, shape, md5_checksum, n_retries, delay, parser, read_csv_kwargs)
#     681     from pandas.errors import ParserError
#     683     no_retry_exception = ParserError
# --> 685 X, y, frame, categories = _retry_with_clean_cache(
#     686     url, data_home, no_retry_exception
#     687 )(_load_arff_response)(
#     688     url,
#     689     data_home,
#     690     parser=parser,
#     691     output_type=output_type,
#     692     openml_columns_info=features_dict,
#     693     feature_names_to_select=data_columns,
#     694     target_names_to_select=target_columns,
#     695     shape=shape,
#     696     md5_checksum=md5_checksum,
#     697     n_retries=n_retries,
#     698     delay=delay,
#     699     read_csv_kwargs=read_csv_kwargs,
#     700 )
#     702 return Bunch(
#     703     data=X,
#     704     target=y,
#    (...)    708     target_names=target_columns,
#     709 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\datasets\_openml.py:66, in _retry_with_clean_cache.<locals>.decorator.<locals>.wrapper(*args, **kw)
#      64     return f(*args, **kw)
#      65 try:
# ---> 66     return f(*args, **kw)
#      67 except URLError:
#      68     raise
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\datasets\_openml.py:520, in _load_arff_response(url, data_home, parser, output_type, openml_columns_info, feature_names_to_select, target_names_to_select, shape, md5_checksum, n_retries, delay, read_csv_kwargs)
#     437 def _load_arff_response(
#     438     url: str,
#     439     data_home: Optional[str],
#    (...)    449     read_csv_kwargs: Optional[Dict] = None,
#     450 ):
#     451     """Load the ARFF data associated with the OpenML URL.
#     452
#     453     In addition of loading the data, this function will also check the
#    (...)    518         `output_array_type == "pandas"`.
#     519     """
# --> 520     gzip_file = _open_openml_url(url, data_home, n_retries=n_retries, delay=delay)
#     521     with closing(gzip_file):
#     522         md5 = hashlib.md5()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\sklearn\datasets\_openml.py:184, in _open_openml_url(url, data_home, n_retries, delay)
#     182                 opener = gzip.GzipFile
#     183             with opener(os.path.join(tmpdir, file_name), "wb") as fdst:
# --> 184                 shutil.copyfileobj(fsrc, fdst)
#     185         shutil.move(fdst.name, local_path)
#     186 except Exception:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\shutil.py:203, in copyfileobj(fsrc, fdst, length)
#     201 fsrc_read = fsrc.read
#     202 fdst_write = fdst.write
# --> 203 while buf := fsrc_read(length):
#     204     fdst_write(buf)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\http\client.py:478, in HTTPResponse.read(self, amt)
#     475     return b""
#     477 if self.chunked:
# --> 478     return self._read_chunked(amt)
#     480 if amt is not None and amt >= 0:
#     481     if self.length is not None and amt > self.length:
#     482         # clip the read to the "end of response"
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\http\client.py:608, in HTTPResponse._read_chunked(self, amt)
#     605     self.chunk_left = chunk_left - amt
#     606     break
# --> 608 value.append(self._safe_read(chunk_left))
#     609 if amt is not None:
#     610     amt -= chunk_left
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\http\client.py:648, in HTTPResponse._safe_read(self, amt)
#     641 """Read the number of bytes requested.
#     642
#     643 This function should be used when <amt> bytes "should" be present for
#     644 reading. If the bytes are truly not available (due to EOF), then the
#     645 IncompleteRead exception can be used to detect the problem.
#     646 """
#     647 cursize = min(amt, _MIN_READ_BUF_SIZE)
# --> 648 data = self.fp.read(cursize)
#     649 if len(data) >= amt:
#     650     return data
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.3312.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:
